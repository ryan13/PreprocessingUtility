# %% [markdown]
# **Pandas revisit** This notebook is aimed at to illustrate what can do with dataframe in efficent way than previous verion. Especially, we will review the use of **transform** with groupby. [see](https://pbpython.com/pandas_transform.html)

# %%
import pandas as pd

# %%
df= pd.read_csv('./Downloads/data/survey_results_public.csv')
schema_df = pd.read_csv('./Downloads/data/survey_results_schema.csv', index_col='Column')

# %%
pd.set_option('display.max_columns', 85)
df.head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 0                       Never
# 1     Less than once per year
# 2                       Never
# 3                       Never
# 4  Once a month or more often
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
# 3  The quality of OSS and closed source software ...
# 4  OSS is, on average, of HIGHER quality than pro...
#
# ...

# %%
df['ConvertedComp'].head(15)
# Out:
# 0          NaN
# 1          NaN
# 2       8820.0
# 3      61000.0
# 4          NaN
# 5     366420.0
# 6          NaN
# 7          NaN
# 8      95179.0
# 9      13293.0
# 10         NaN
# 11         NaN
# 12     90000.0
# 13     57060.0
# 14         NaN
# Name: ConvertedComp, dtype: float64

# %%
df['ConvertedComp'].median()
# Out:
# 57287.0

# %%
df.median()
# Out:
# Respondent       44442.0
# CompTotal        62000.0
# ConvertedComp    57287.0
# WorkWeekHrs         40.0
# CodeRevHrs           4.0
# Age                 29.0
# dtype: float64

# %%
df.describe()
# Out:
#          Respondent     CompTotal  ConvertedComp   WorkWeekHrs    CodeRevHrs  \
# count  88883.000000  5.594500e+04   5.582300e+04  64503.000000  49790.000000
# mean   44442.000000  5.519014e+11   1.271107e+05     42.127197      5.084308
# std    25658.456325  7.331926e+13   2.841523e+05     37.287610      5.513931
# min        1.000000  0.000000e+00   0.000000e+00      1.000000      0.000000
# 25%    22221.500000  2.000000e+04   2.577750e+04     40.000000      2.000000
# 50%    44442.000000  6.200000e+04   5.728700e+04     40.000000      4.000000
# 75%    66662.500000  1.200000e+05   1.000000e+05     44.750000      6.000000
# max    88883.000000  1.000000e+16   2.000000e+06   4850.000000     99.000000
#
#                 Age
# count  79210.000000
# mean      30.336699
# std        9.178390
# min        1.000000
# 25%       24.000000
# 50%       29.000000
# 75%       35.000000
# max       99.000000

# %%
# Note: we have ConvertedComp containing salary converted into US dollar
df['ConvertedComp'].count()
# Out:
# 55823

# %% [markdown]
# ### We may change to see what people want to code at free time or not by

# %%
df['Hobbyist']
# Out:
# 0        Yes
# 1         No
# 2        Yes
# 3         No
# 4        Yes
#         ...
# 88878    Yes
# 88879     No
# 88880     No
# 88881     No
# 88882    Yes
# Name: Hobbyist, Length: 88883, dtype: object

# %% [markdown]
# ### We can see how many people code for a hobby

# %%
df['Hobbyist'].value_counts()
# Out:
# Yes    71257
# No     17626
# Name: Hobbyist, dtype: int64

# %%
df['SocialMedia']
# Out:
# 0          Twitter
# 1        Instagram
# 2           Reddit
# 3           Reddit
# 4         Facebook
#            ...
# 88878      YouTube
# 88879          NaN
# 88880          NaN
# 88881          NaN
# 88882     WhatsApp
# Name: SocialMedia, Length: 88883, dtype: object

# %% [markdown]
# ### To see what question to ask for Social Media

# %%
schema_df.loc['SocialMedia']
# Out:
# QuestionText    What social media site do you use the most?
# Name: SocialMedia, dtype: object

# %%
df['SocialMedia'].value_counts()
# Out:
# Reddit                      14374
# YouTube                     13830
# WhatsApp                    13347
# Facebook                    13178
# Twitter                     11398
# Instagram                    6261
# I don't use social media     5554
# LinkedIn                     4501
# WeChat 微信                     667
# Snapchat                      628
# VK ВКонта́кте                 603
# Weibo 新浪微博                     56
# Youku Tudou 优酷                 21
# Hello                          19
# Name: SocialMedia, dtype: int64

# %%
df['SocialMedia'].value_counts(normalize=True)
# Out:
# Reddit                      0.170233
# YouTube                     0.163791
# WhatsApp                    0.158071
# Facebook                    0.156069
# Twitter                     0.134988
# Instagram                   0.074150
# I don't use social media    0.065777
# LinkedIn                    0.053306
# WeChat 微信                   0.007899
# Snapchat                    0.007437
# VK ВКонта́кте               0.007141
# Weibo 新浪微博                  0.000663
# Youku Tudou 优酷              0.000249
# Hello                       0.000225
# Name: SocialMedia, dtype: float64

# %%
df['Country'].value_counts()
# Out:
# United States                       20949
# India                                9061
# Germany                              5866
# United Kingdom                       5737
# Canada                               3395
#                                     ...
# Papua New Guinea                        1
# Dominica                                1
# Tonga                                   1
# Saint Vincent and the Grenadines        1
# Chad                                    1
# Name: Country, Length: 179, dtype: int64

# %% [markdown]
# ### groupby based on country & how to get group with get_group

# %%
country_grp = df.groupby(['Country'])
country_grp.get_group('United States')
# Out:
#        Respondent                      MainBranch Hobbyist  \
# 3               4  I am a developer by profession       No
# 12             13  I am a developer by profession      Yes
# 21             22  I am a developer by profession      Yes
# 22             23  I am a developer by profession      Yes
# 25             26  I am a developer by profession      Yes
# ...           ...                             ...      ...
# 88818       78292                             NaN       No
# 88840       82717                             NaN       No
# 88844       83397                             NaN      Yes
# 88859       85642                             NaN       No
# 88877       88282                             NaN      Yes
#
#                                              OpenSourcer  \
# 3                                                  Never
# 12     Less than once a month but more than once per ...
# 21                               Less than once per year
# ...

# %% [markdown]
# ### To show only the count of each social media for United States we can use

# %%
filt = df['Country'] == 'United States'
df.loc[filt]['SocialMedia'].value_counts()
# Out:
# Reddit                      5700
# Twitter                     3468
# Facebook                    2844
# YouTube                     2463
# I don't use social media    1851
# Instagram                   1652
# LinkedIn                    1020
# WhatsApp                     609
# Snapchat                     326
# WeChat 微信                     93
# VK ВКонта́кте                  9
# Weibo 新浪微博                     8
# Hello                          2
# Youku Tudou 优酷                 1
# Name: SocialMedia, dtype: int64

# %% [markdown]
# ### Show the percentage of each type of social media channel in China

# %%
country_grp['SocialMedia'].value_counts(normalize=True).loc['China']
# Out:
# SocialMedia
# WeChat 微信                   0.670549
# YouTube                     0.088186
# Weibo 新浪微博                  0.069884
# I don't use social media    0.044925
# Twitter                     0.044925
# Reddit                      0.019967
# LinkedIn                    0.018303
# Facebook                    0.013311
# Instagram                   0.011647
# Youku Tudou 优酷              0.011647
# WhatsApp                    0.004992
# VK ВКонта́кте               0.001664
# Name: SocialMedia, dtype: float64

# %% [markdown]
# ### We can see number of social media on each country

# %%
country_grp['SocialMedia'].value_counts().head(50)
# Out:
# Country              SocialMedia
# Afghanistan          Facebook                     15
#                      YouTube                       9
#                      I don't use social media      6
#                      WhatsApp                      4
#                      Instagram                     1
#                      LinkedIn                      1
#                      Twitter                       1
# Albania              WhatsApp                     18
#                      Facebook                     16
#                      Instagram                    13
#                      YouTube                      10
#                      Twitter                       8
#                      LinkedIn                      7
#                      Reddit                        6
#                      I don't use social media      4
#                      Snapchat                      1
#                      WeChat 微信                     1
# ...

# %% [markdown]
# ### What is median salary in Germany

# %%
country_grp['ConvertedComp'].median().loc['Germany']
# Out:
# 63016.0

# %% [markdown]
# ### We even want to find both median and mean for Canada

# %%
country_grp['ConvertedComp'].agg(['median', 'mean']).loc['Canada']
# Out:
# median     68705.000000
# mean      134018.564909
# Name: Canada, dtype: float64

# %% [markdown]
# ### We may want to which language people used for coding in India as

# %%
filt = df['Country'] == 'India'
df.loc[filt]['LanguageWorkedWith']
# Out:
# 7        Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
# 9                            C#;Go;JavaScript;Python;R;SQL
# 14       Assembly;Bash/Shell/PowerShell;C;C++;HTML/CSS;...
# 49       Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
# 64                         Assembly;C;C++;C#;HTML/CSS;Java
#                                ...
# 88808                                            Other(s):
# 88825                 Bash/Shell/PowerShell;Python;SQL;VBA
# 88852    Assembly;C;C++;HTML/CSS;Java;JavaScript;Object...
# 88853     HTML/CSS;Java;JavaScript;Python;Swift;TypeScript
# 88864        Bash/Shell/PowerShell;C++;HTML/CSS;JavaScript
# Name: LanguageWorkedWith, Length: 9061, dtype: object

# %% [markdown]
# ### How many people in India use python

# %%
filt = df['Country'] == 'India'
df.loc[filt]['LanguageWorkedWith'].str.contains('Python').sum()
# Out:
# 3105

# %% [markdown]
# ### Note: To check wheter a person in India use Python to code

# %%
df.loc[filt]['LanguageWorkedWith'].str.contains('Python')
# Out:
# 7         True
# 9         True
# 14       False
# 49        True
# 64       False
#          ...
# 88808    False
# 88825     True
# 88852    False
# 88853     True
# 88864    False
# Name: LanguageWorkedWith, Length: 9061, dtype: object

# %% [markdown]
# ###  we may want to  count the number of python programmers for each country by
# Note: We intend to leave error in this cell to explain

# %%
country_grp['LanguageWorkedWith'].str.contains('Python').sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-cda55dd00399> in <module>
# ----> 1 country_grp['LanguageWorkedWith'].str.contains('Python').sum()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in __getattr__(self, attr)
#     578
#     579         raise AttributeError(
# --> 580             f"'{type(self).__name__}' object has no attribute '{attr}'"
#     581         )
#     582
#
# AttributeError: 'SeriesGroupBy' object has no attribute 'str'

# %% [markdown]
# However, we can see that the SeriesGroupBy does not support str, that we need to use apply

# %%
country_grp['LanguageWorkedWith']

# %%
country_grp['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').sum())
# Out:
# Country
# Afghanistan                              8
# Albania                                 23
# Algeria                                 40
# Andorra                                  0
# Angola                                   2
#                                         ..
# Venezuela, Bolivarian Republic of...    28
# Viet Nam                                78
# Yemen                                    3
# Zambia                                   4
# Zimbabwe                                14
# Name: LanguageWorkedWith, Length: 179, dtype: int64

# %% [markdown]
# ### What % of people who use Python as language for each country?

# %%
country_respondents = df['Country'].value_counts()
country_respondents
# Out:
# United States                       20949
# India                                9061
# Germany                              5866
# United Kingdom                       5737
# Canada                               3395
#                                     ...
# Papua New Guinea                        1
# Dominica                                1
# Tonga                                   1
# Saint Vincent and the Grenadines        1
# Chad                                    1
# Name: Country, Length: 179, dtype: int64

# %%
country_uses_python = country_grp['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').sum())
country_uses_python
# Out:
# Country
# Afghanistan                              8
# Albania                                 23
# Algeria                                 40
# Andorra                                  0
# Angola                                   2
#                                         ..
# Venezuela, Bolivarian Republic of...    28
# Viet Nam                                78
# Yemen                                    3
# Zambia                                   4
# Zimbabwe                                14
# Name: LanguageWorkedWith, Length: 179, dtype: int64

# %%
python_df = pd.concat([country_respondents, country_uses_python], axis='columns', sort=False)
python_df
# Out:
#                                   Country  LanguageWorkedWith
# United States                       20949               10083
# India                                9061                3105
# Germany                              5866                2451
# United Kingdom                       5737                2384
# Canada                               3395                1558
# ...                                   ...                 ...
# Papua New Guinea                        1                   0
# Dominica                                1                   1
# Tonga                                   1                   0
# Saint Vincent and the Grenadines        1                   0
# Chad                                    1                   0
#
# [179 rows x 2 columns]

# %%
python_df.rename(columns={'Country': 'NumRespondents', 'LanguageWorkedWith': 'NumKnowsPython'}, inplace=True)

# %%
python_df
# Out:
#                                   NumRespondents  NumKnowsPython
# United States                              20949           10083
# India                                       9061            3105
# Germany                                     5866            2451
# United Kingdom                              5737            2384
# Canada                                      3395            1558
# ...                                          ...             ...
# Papua New Guinea                               1               0
# Dominica                                       1               1
# Tonga                                          1               0
# Saint Vincent and the Grenadines               1               0
# Chad                                           1               0
#
# [179 rows x 2 columns]

# %% [markdown]
# ### We can compute percentage of people using Python for each country

# %%
python_df['PctKnowsPython'] = (python_df['NumKnowsPython']/python_df['NumRespondents']) * 100
python_df
# Out:
#                                   NumRespondents  NumKnowsPython  \
# United States                              20949           10083
# India                                       9061            3105
# Germany                                     5866            2451
# United Kingdom                              5737            2384
# Canada                                      3395            1558
# ...                                          ...             ...
# Papua New Guinea                               1               0
# Dominica                                       1               1
# Tonga                                          1               0
# Saint Vincent and the Grenadines               1               0
# Chad                                           1               0
#
#                                   PctKnowsPython
# United States                          48.131176
# India                                  34.267741
# ...

# %%
python_df.sort_values(by='PctKnowsPython', ascending=False, inplace=True)
python_df.head()
# Out:
#                        NumRespondents  NumKnowsPython  PctKnowsPython
# Dominica                            1               1      100.000000
# Niger                               1               1      100.000000
# Sao Tome and Principe               1               1      100.000000
# Timor-Leste                         1               1      100.000000
# Turkmenistan                        7               6       85.714286

# %%
python_df.loc['Japan']
# Out:
# NumRespondents    391.000000
# NumKnowsPython    182.000000
# PctKnowsPython     46.547315
# Name: Japan, dtype: float64

# %% [markdown]
# ## Extend Question
# How to calculate **percentage of each language used vs overall users in each country**.
# Since above solution can calculate % only for one language (e.g. Python) on each country. Each country may have a set of programming languages (exclude those language nobody used).
#
# Approach: use **groupby** with **transform**. [credit](https://pbpython.com/pandas_transform.html) Read : Groupby_transform_datafram.ipynb

# %%
df.columns.values
# Out:
# array(['Respondent', 'MainBranch', 'Hobbyist', 'OpenSourcer',
#        'OpenSource', 'Employment', 'Country', 'Student', 'EdLevel',
#        'UndergradMajor', 'EduOther', 'OrgSize', 'DevType', 'YearsCode',
#        'Age1stCode', 'YearsCodePro', 'CareerSat', 'JobSat', 'MgrIdiot',
#        'MgrMoney', 'MgrWant', 'JobSeek', 'LastHireDate', 'LastInt',
#        'FizzBuzz', 'JobFactors', 'ResumeUpdate', 'CurrencySymbol',
#        'CurrencyDesc', 'CompTotal', 'CompFreq', 'ConvertedComp',
#        'WorkWeekHrs', 'WorkPlan', 'WorkChallenge', 'WorkRemote',
#        'WorkLoc', 'ImpSyn', 'CodeRev', 'CodeRevHrs', 'UnitTests',
#        'PurchaseHow', 'PurchaseWhat', 'LanguageWorkedWith',
#        'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
filt = df['Country'] == 'India'
df.groupby('Country').get_group('United States')['LanguageWorkedWith'].str.split(";")
# Out:
# 3                                [C, C++, C#, Python, SQL]
# 12       [Bash/Shell/PowerShell, HTML/CSS, JavaScript, ...
# 21       [Bash/Shell/PowerShell, C++, HTML/CSS, JavaScr...
# 22       [Bash/Shell/PowerShell, HTML/CSS, JavaScript, ...
# 25       [Bash/Shell/PowerShell, C++, C#, HTML/CSS, Jav...
#                                ...
# 88818                   [Bash/Shell/PowerShell, C, Python]
# 88840                                                  NaN
# 88844                  [HTML/CSS, JavaScript, Python, SQL]
# 88859                                       [Go, HTML/CSS]
# 88877    [Bash/Shell/PowerShell, Go, HTML/CSS, JavaScri...
# Name: LanguageWorkedWith, Length: 20949, dtype: object

# %% [markdown]
# credit [Source](https://stackoverflow.com/questions/12680754/split-explode-pandas-dataframe-string-entry-to-separate-rows) Solution to generate multiple rows from one columns similar to explode method in Spark

# %%
import numpy as np
def explode(df, lst_cols, fill_value='', preserve_index=False):
    # make sure `lst_cols` is list-alike
    if (lst_cols is not None
        and len(lst_cols) > 0
        and not isinstance(lst_cols, (list, tuple, np.ndarray, pd.Series))):
        lst_cols = [lst_cols]
    # all columns except `lst_cols`
    idx_cols = df.columns.difference(lst_cols)
    # calculate lengths of lists
    lens = df[lst_cols[0]].str.len()
    # preserve original index values    
    idx = np.repeat(df.index.values, lens)
    # create "exploded" DF
    res = (pd.DataFrame({
                col:np.repeat(df[col].values, lens)
                for col in idx_cols},
                index=idx)
             .assign(**{col:np.concatenate(df.loc[lens>0, col].values)
                            for col in lst_cols}))
    # append those rows that have empty lists
    if (lens == 0).any():
        # at least one list in cells is empty
        res = (res.append(df.loc[lens==0, idx_cols], sort=False)
                  .fillna(fill_value))
    # revert the original index order
    res = res.sort_index()
    # reset index if requested
    if not preserve_index:        
        res = res.reset_index(drop=True)
    return res

# %%
df = pd.DataFrame({
 'aaa': {0: 10, 1: 11, 2: 12, 3: 13},
 'myid': {0: 1, 1: 2, 2: 3, 3: 4},
 'num': {0: [1, 2, 3], 1: [], 2: [1, 2], 3: []},
 'text': {0: ['aa', 'bb', 'cc'], 1: [], 2: ['cc', 'dd'], 3: []}
})
df
# Out:
#    aaa  myid        num          text
# 0   10     1  [1, 2, 3]  [aa, bb, cc]
# 1   11     2         []            []
# 2   12     3     [1, 2]      [cc, dd]
# 3   13     4         []            []

# %%
df = pd.DataFrame(
       [{'var1': 'a,b,c', 'var2': 1, 'var3': 'XX'},
       {'var1': 'd,e,f,x,y', 'var2': 2, 'var3': 'ZZ'}]
   )
df
# Out:
#         var1  var2 var3
# 0      a,b,c     1   XX
# 1  d,e,f,x,y     2   ZZ

# %%
explode(df.assign(var1=df.var1.str.split(',')), 'var1')
# Out:
#    var2 var3 var1
# 0     1   XX    a
# 1     1   XX    b
# 2     1   XX    c
# 3     2   ZZ    d
# 4     2   ZZ    e
# 5     2   ZZ    f
# 6     2   ZZ    x
# 7     2   ZZ    y

# %% [markdown]
# Simple solution

# %%
(df.set_index(df.columns.drop('var1',1).tolist())
      .var1.str.split(',', expand=True)
      .stack()
      .reset_index()
      .rename(columns={0:'var1'})
      .loc[:, df.columns]
   )
# Out:
#   var1  var2 var3
# 0    a     1   XX
# 1    b     1   XX
# 2    c     1   XX
# 3    d     2   ZZ
# 4    e     2   ZZ
# 5    f     2   ZZ
# 6    x     2   ZZ
# 7    y     2   ZZ

# %% [markdown]
# Now we can use the same approach to find the number of people who use each language'
